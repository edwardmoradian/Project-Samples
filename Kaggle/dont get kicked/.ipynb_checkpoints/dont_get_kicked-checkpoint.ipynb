# %%
import numpy as np
import sklearn as sk
from sklearn import preprocessing
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay
from sklearn.model_selection  import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
import optuna

# %% [markdown]
# ## Load Data

# %%
pd.set_option('display.max_columns', None)

# %%
df_test = pd.read_csv('C:/Users/Edward.Moradian/OneDrive - Microsoft/Desktop/Home/Practice/kaggle/kicked/test.csv')

# %%
df_training = pd.read_csv('C:/Users/Edward.Moradian/OneDrive - Microsoft/Desktop/Home/Practice/kaggle/kicked/training.csv')

# %%
df_training
# Out:
#        RefId  IsBadBuy  PurchDate Auction  VehYear  VehicleAge       Make  \
# 0          1         0  12/7/2009   ADESA     2006           3      MAZDA
# 1          2         0  12/7/2009   ADESA     2004           5      DODGE
# 2          3         0  12/7/2009   ADESA     2005           4      DODGE
# 3          4         0  12/7/2009   ADESA     2004           5      DODGE
# 4          5         0  12/7/2009   ADESA     2005           4       FORD
# ...      ...       ...        ...     ...      ...         ...        ...
# 72978  73010         1  12/2/2009   ADESA     2001           8    MERCURY
# 72979  73011         0  12/2/2009   ADESA     2007           2  CHEVROLET
# 72980  73012         0  12/2/2009   ADESA     2005           4       JEEP
# 72981  73013         0  12/2/2009   ADESA     2006           3  CHEVROLET
# 72982  73014         0  12/2/2009   ADESA     2006           3      MAZDA
#
#                       Model Trim           SubModel   Color Transmission  \
# 0                    MAZDA3    i         4D SEDAN I     RED         AUTO
# 1       1500 RAM PICKUP 2WD   ST  QUAD CAB 4.7L SLT   WHITE         AUTO
# 2                STRATUS V6  SXT   4D SEDAN SXT FFV  MAROON         AUTO
# 3                      NEON  SXT           4D SEDAN  SILVER         AUTO
# 4                     FOCUS  ZX3       2D COUPE ZX3  SILVER       MANUAL
# ...                     ...  ...                ...     ...          ...
# 72978                 SABLE   GS        4D SEDAN GS   BLACK         AUTO
# 72979             MALIBU 4C   LS        4D SEDAN LS  SILVER         AUTO
# 72980  GRAND CHEROKEE 2WD V  Lar    4D WAGON LAREDO  SILVER         AUTO
# 72981                IMPALA   LS        4D SEDAN LS   WHITE         AUTO
# 72982                MAZDA6    s         4D SEDAN S  SILVER         AUTO
#
#        WheelTypeID WheelType  VehOdo  Nationality         Size  \
# 0              1.0     Alloy   89046  OTHER ASIAN       MEDIUM
# 1              1.0     Alloy   93593     AMERICAN  LARGE TRUCK
# 2              2.0    Covers   73807     AMERICAN       MEDIUM
# 3              1.0     Alloy   65617     AMERICAN      COMPACT
# 4              2.0    Covers   69367     AMERICAN      COMPACT
# ...            ...       ...     ...          ...          ...
# 72978          1.0     Alloy   45234     AMERICAN       MEDIUM
# 72979          NaN       NaN   71759     AMERICAN       MEDIUM
# 72980          1.0     Alloy   88500     AMERICAN   MEDIUM SUV
# 72981          1.0     Alloy   79554     AMERICAN        LARGE
# 72982          1.0     Alloy   66855  OTHER ASIAN       MEDIUM
#
#       TopThreeAmericanName  MMRAcquisitionAuctionAveragePrice  \
# 0                    OTHER                             8155.0
# 1                 CHRYSLER                             6854.0
# 2                 CHRYSLER                             3202.0
# 3                 CHRYSLER                             1893.0
# 4                     FORD                             3913.0
# ...                    ...                                ...
# 72978                 FORD                             1996.0
# 72979                   GM                             6418.0
# 72980             CHRYSLER                             8545.0
# 72981                   GM                             6420.0
# 72982                OTHER                             7535.0
#
#        MMRAcquisitionAuctionCleanPrice  MMRAcquisitionRetailAveragePrice  \
# 0                               9829.0                           11636.0
# 1                               8383.0                           10897.0
# 2                               4760.0                            6943.0
# 3                               2675.0                            4658.0
# 4                               5054.0                            7723.0
# ...                                ...                               ...
# 72978                           2993.0                            2656.0
# 72979                           7325.0                            7431.0
# 72980                           9959.0                            9729.0
# 72981                           7604.0                            7434.0
# 72982                           8771.0                            8638.0
#
#        MMRAcquisitonRetailCleanPrice  MMRCurrentAuctionAveragePrice  \
# 0                            13600.0                         7451.0
# 1                            12572.0                         7456.0
# 2                             8457.0                         4035.0
# 3                             5690.0                         1844.0
# 4                             8707.0                         3247.0
# ...                              ...                            ...
# 72978                         3732.0                         2190.0
# 72979                         8411.0                         6785.0
# 72980                        11256.0                         8375.0
# 72981                         8712.0                         6590.0
# 72982                         9973.0                         7730.0
#
#        MMRCurrentAuctionCleanPrice  MMRCurrentRetailAveragePrice  \
# 0                           8552.0                       11597.0
# 1                           9222.0                       11374.0
# 2                           5557.0                        7146.0
# 3                           2646.0                        4375.0
# 4                           4384.0                        6739.0
# ...                            ...                           ...
# 72978                       3055.0                        4836.0
# 72979                       8132.0                       10151.0
# 72980                       9802.0                       11831.0
# 72981                       7684.0                       10099.0
# 72982                       9102.0                       11954.0
#
#        MMRCurrentRetailCleanPrice PRIMEUNIT AUCGUART  BYRNO  VNZIP1 VNST  \
# 0                         12409.0       NaN      NaN  21973   33619   FL
# 1                         12791.0       NaN      NaN  19638   33619   FL
# 2                          8702.0       NaN      NaN  19638   33619   FL
# 3                          5518.0       NaN      NaN  19638   33619   FL
# 4                          7911.0       NaN      NaN  19638   33619   FL
# ...                           ...       ...      ...    ...     ...  ...
# 72978                      5937.0       NaN      NaN  18111   30212   GA
# 72979                     11652.0       NaN      NaN  18881   30212   GA
# 72980                     14402.0       NaN      NaN  18111   30212   GA
# 72981                     11228.0       NaN      NaN  18881   30212   GA
# 72982                     13246.0       NaN      NaN  18111   30212   GA
#
#        VehBCost  IsOnlineSale  WarrantyCost
# 0        7100.0             0          1113
# 1        7600.0             0          1053
# 2        4900.0             0          1389
# 3        4100.0             0           630
# 4        4000.0             0          1020
# ...         ...           ...           ...
# 72978    4200.0             0           993
# 72979    6200.0             0          1038
# 72980    8200.0             0          1893
# 72981    7000.0             0          1974
# 72982    8000.0             0          1313
#
# [72983 rows x 34 columns]

# %%
df_training.dtypes
# Out:
# RefId                                  int64
# IsBadBuy                               int64
# PurchDate                             object
# Auction                               object
# VehYear                                int64
# VehicleAge                             int64
# Make                                  object
# Model                                 object
# Trim                                  object
# SubModel                              object
# Color                                 object
# Transmission                          object
# WheelTypeID                          float64
# WheelType                             object
# VehOdo                                 int64
# Nationality                           object
# Size                                  object
# TopThreeAmericanName                  object
# MMRAcquisitionAuctionAveragePrice    float64
# MMRAcquisitionAuctionCleanPrice      float64
# MMRAcquisitionRetailAveragePrice     float64
# MMRAcquisitonRetailCleanPrice        float64
# MMRCurrentAuctionAveragePrice        float64
# MMRCurrentAuctionCleanPrice          float64
# MMRCurrentRetailAveragePrice         float64
# MMRCurrentRetailCleanPrice           float64
# PRIMEUNIT                             object
# AUCGUART                              object
# BYRNO                                  int64
# VNZIP1                                 int64
# VNST                                  object
# VehBCost                             float64
# IsOnlineSale                           int64
# WarrantyCost                           int64
# dtype: object

# %%
df_training['WheelTypeID'].unique()
# Out:
# array([ 1.,  2., nan,  3.,  0.])

# %%
df_training['IsBadBuy'] = df_training['IsBadBuy'].astype('str')
df_training['RefId'] = df_training['RefId'].astype('str')
df_training['WheelTypeID'] = df_training['WheelTypeID'].astype('str')
df_training['BYRNO'] = df_training['BYRNO'].astype('str')
df_training['VNZIP1'] = df_training['VNZIP1'].astype('str')
df_training['IsOnlineSale'] = df_training['IsOnlineSale'].astype('str')

# %%
df_training['IsBadBuy'].unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
df_training.loc[df_training.loc[:,'IsBadBuy'].isna(),'IsBadBuy'] = None

# %%
df_training.loc[df_training['IsBadBuy'].isna(),'IsBadBuy']
# Out:
# Series([], Name: IsBadBuy, dtype: object)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_training['IsBadBuy'].value_counts(dropna=False)
# Out:
# 0    64007
# 1     8976
# Name: IsBadBuy, dtype: int64

# %%
df_training['IsBadBuy'].value_counts(normalize=True,dropna=False)
# Out:
# 0    0.877012
# 1    0.122988
# Name: IsBadBuy, dtype: float64

# %% [markdown]
# #### Majority of Buys are a good buy.  BadBuy is not very low frequency to be an anomaly.

# %%
df_training['IsBadBuy'].value_counts(normalize=True,dropna=False).plot(kind='pie',autopct='%.1f',figsize=(8,6))
# Out:
# <AxesSubplot:ylabel='IsBadBuy'>

# %%
df_training.columns.sort_values()
# Out:
# Index(['AUCGUART', 'Auction', 'BYRNO', 'Color', 'IsBadBuy', 'IsOnlineSale',
#        'MMRAcquisitionAuctionAveragePrice', 'MMRAcquisitionAuctionCleanPrice',
#        'MMRAcquisitionRetailAveragePrice', 'MMRAcquisitonRetailCleanPrice',
#        'MMRCurrentAuctionAveragePrice', 'MMRCurrentAuctionCleanPrice',
#        'MMRCurrentRetailAveragePrice', 'MMRCurrentRetailCleanPrice', 'Make',
#        'Model', 'Nationality', 'PRIMEUNIT', 'PurchDate', 'RefId', 'Size',
#        'SubModel', 'TopThreeAmericanName', 'Transmission', 'Trim', 'VNST',
#        'VNZIP1', 'VehBCost', 'VehOdo', 'VehYear', 'VehicleAge', 'WarrantyCost',
#        'WheelType', 'WheelTypeID'],
#       dtype='object')

# %%
df_training.dtypes.items()

# %%
dim_cols = df_training.loc[:,df_training.dtypes == 'object'].columns
fact_cols = df_training.loc[:,df_training.dtypes != 'object'].columns
dim_cols_2 = dim_cols.copy().drop('IsBadBuy')

# %%
fact_cols
# Out:
# Index(['VehYear', 'VehicleAge', 'VehOdo', 'MMRAcquisitionAuctionAveragePrice',
#        'MMRAcquisitionAuctionCleanPrice', 'MMRAcquisitionRetailAveragePrice',
#        'MMRAcquisitonRetailCleanPrice', 'MMRCurrentAuctionAveragePrice',
#        'MMRCurrentAuctionCleanPrice', 'MMRCurrentRetailAveragePrice',
#        'MMRCurrentRetailCleanPrice', 'VehBCost', 'WarrantyCost'],
#       dtype='object')

# %%
dim_cols
# Out:
# Index(['RefId', 'IsBadBuy', 'PurchDate', 'Auction', 'Make', 'Model', 'Trim',
#        'SubModel', 'Color', 'Transmission', 'WheelTypeID', 'WheelType',
#        'Nationality', 'Size', 'TopThreeAmericanName', 'PRIMEUNIT', 'AUCGUART',
#        'BYRNO', 'VNZIP1', 'VNST', 'IsOnlineSale'],
#       dtype='object')

# %% [markdown]
# #### Vehicle Age for bad buys is slighlty older by about 1 year. Vehicle Cost has more extreme value outliers for bad buys and a higher mean. Warranty costs are lower for bad buys.

# %%
df_training.loc[df_training.loc[:,'IsBadBuy'] == '1',:].describe()
# Out:
#            VehYear   VehicleAge         VehOdo  \
# count  8976.000000  8976.000000    8976.000000
# mean   2004.608512     4.940954   74714.148173
# std       1.776551     1.765302   14150.973362
# min    2001.000000     1.000000    4825.000000
# 25%    2003.000000     4.000000   65978.000000
# 50%    2005.000000     5.000000   76545.500000
# 75%    2006.000000     6.000000   84942.000000
# max    2009.000000     9.000000  115717.000000
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionAuctionCleanPrice  \
# count                        8975.000000                      8975.000000
# mean                         5410.697604                      6625.218942
# std                          2648.702459                      2941.060152
# min                             0.000000                         0.000000
# 25%                          3475.000000                      4516.000000
# 50%                          5005.000000                      6203.000000
# 75%                          6993.000000                      8276.500000
# max                         35722.000000                     36859.000000
#
#        MMRAcquisitionRetailAveragePrice  MMRAcquisitonRetailCleanPrice  \
# count                       8975.000000                    8975.000000
# mean                        7760.293148                    9094.547744
# std                         3346.761225                    3615.830060
# min                            0.000000                       0.000000
# 25%                         5401.000000                    6595.000000
# 50%                         7453.000000                    8826.000000
# 75%                         9884.000000                   11322.500000
# max                        39080.000000                   41482.000000
#
#        MMRCurrentAuctionAveragePrice  MMRCurrentAuctionCleanPrice  \
# count                    8944.000000                  8944.000000
# mean                     5423.031194                  6644.840452
# std                      2592.306354                  2875.176655
# min                         0.000000                     0.000000
# 25%                      3487.000000                  4554.000000
# 50%                      5015.500000                  6211.000000
# 75%                      6960.000000                  8262.250000
# max                     35722.000000                 36859.000000
#
#        MMRCurrentRetailAveragePrice  MMRCurrentRetailCleanPrice      VehBCost  \
# count                   8944.000000                 8944.000000   8976.000000
# mean                    7918.462545                 9259.641883   6259.274157
# std                     3268.131003                 3519.830641   2078.955281
# min                        0.000000                    0.000000      1.000000
# 25%                     5600.750000                 6787.750000   4765.000000
# 50%                     7623.000000                 8984.000000   6000.000000
# 75%                     9961.750000                11430.000000   7505.000000
# max                    39080.000000                41062.000000  45469.000000
#
#        WarrantyCost
# count   8976.000000
# mean    1360.246546
# std      679.894543
# min      462.000000
# 25%      909.000000
# 50%     1243.000000
# 75%     1647.250000
# max     6492.000000

# %%
df_training.loc[df_training.loc[:,'IsBadBuy'] == '0',:].describe() - df_training.loc[df_training.loc[:,'IsBadBuy'] == '1',:].describe()
# Out:
#             VehYear    VehicleAge        VehOdo  \
# count  55031.000000  55031.000000  55031.000000
# mean       0.837549     -0.871493  -3664.887811
# std       -0.076927     -0.088277    430.524507
# min        0.000000     -1.000000    543.000000
# 25%        1.000000     -1.000000  -4675.500000
# 50%        1.000000     -1.000000  -3665.500000
# 75%        1.000000     -1.000000  -2931.500000
# max        1.000000      0.000000  -2100.000000
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionAuctionCleanPrice  \
# count                       55015.000000                     55015.000000
# mean                          818.945308                       853.387294
# std                          -231.020839                      -267.318565
# min                             0.000000                         0.000000
# 25%                           948.250000                      1071.000000
# 50%                          1235.500000                      1247.000000
# 75%                           848.000000                       798.500000
# max                        -15395.000000                    -12844.000000
#
#        MMRAcquisitionRetailAveragePrice  MMRAcquisitonRetailCleanPrice  \
# count                      55015.000000                   55015.000000
# mean                         840.073769                     862.467618
# std                         -231.994948                    -277.212261
# min                            0.000000                       0.000000
# 25%                         1015.000000                    1016.000000
# 50%                         1117.000000                    1094.000000
# 75%                          841.000000                     855.500000
# max                       -14350.000000                  -13969.000000
#
#        MMRCurrentAuctionAveragePrice  MMRCurrentAuctionCleanPrice  \
# count                   54780.000000                 54780.000000
# mean                      808.569019                   850.524152
# std                      -197.423832                  -233.292617
# min                         0.000000                     0.000000
# 25%                       927.000000                  1023.000000
# 50%                      1191.500000                  1239.000000
# 75%                       844.000000                   821.750000
# max                    -13885.000000                -11012.000000
#
#        MMRCurrentRetailAveragePrice  MMRCurrentRetailCleanPrice      VehBCost  \
# count                  54780.000000                54780.000000  55031.000000
# mean                     977.581866                 1010.062200    537.803274
# std                     -222.374871                 -259.233215   -369.585752
# min                        0.000000                    0.000000   1399.000000
# 25%                     1083.250000                 1170.250000    760.000000
# 50%                     1266.000000                 1284.000000    800.000000
# 75%                     1061.500000                  971.000000    435.000000
# max                   -14996.000000               -12647.000000 -29124.000000
#
#        WarrantyCost
# count  55031.000000
# mean     -95.398373
# std      -94.256971
# min        0.000000
# 25%      -75.000000
# 50%      -88.000000
# 75%      -34.250000
# max     1006.000000

# %%
for feature in fact_cols.values:
    plt.figure(figsize=(30,7))
    plt.xticks(rotation='vertical')
    sns.boxplot(x='IsBadBuy',y=feature,data=df_training, palette='rainbow') #,showfliers=False)
    plt.title(feature + " by IsBadBuy")

# %%
df_training['SubModel'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0               4D SEDAN I
# 1        QUAD CAB 4.7L SLT
# 2         4D SEDAN SXT FFV
# 3                 4D SEDAN
# 4             2D COUPE ZX3
#                ...
# 72978          4D SEDAN GS
# 72979          4D SEDAN LS
# 72980      4D WAGON LAREDO
# 72981          4D SEDAN LS
# 72982           4D SEDAN S
# Name: SubModel, Length: 72983, dtype: object>

# %% [markdown]
# #### For dimension columns, bad buys tend to be older vehicles with more cars with wheels with covers. WheelType is possibly a high influence feature.

# %%
print('--- '+dim+' ---')
print(df_training[dim].nunique())
sig_diff = df_training.loc[df_training.loc[:,'IsBadBuy'] == '0','WheelType'].value_counts(normalize=True,dropna=False) - df_training.loc[df_training.loc[:,'IsBadBuy'] == '1','WheelType'].value_counts(normalize=True,dropna=False)
print(sig_diff[(sig_diff > .01) | (sig_diff < -.01)])
print()
# Out:
# --- IsOnlineSale ---
# 2
# Alloy     0.056999
# Covers    0.178362
# NaN      -0.234581
# Name: WheelType, dtype: float64

# %%
for dim in dim_cols:
    print('--- '+dim+' ---')
    print(df_training[dim].nunique())
    sig_diff = abs(df_training.loc[df_training.loc[:,'IsBadBuy'] == '0',dim].value_counts(normalize=True,dropna=False) - df_training.loc[df_training.loc[:,'IsBadBuy'] == '1',dim].value_counts(normalize=True,dropna=False))
    print((sig_diff[sig_diff > .01]))
    print()
# Out:
# --- RefId ---
# 72983
# Series([], Name: RefId, dtype: float64)
#
# --- IsBadBuy ---
# 2
# Series([], Name: IsBadBuy, dtype: float64)
#
# --- PurchDate ---
# 517
# Series([], Name: PurchDate, dtype: float64)
#
# --- Auction ---
# 3
# ADESA      0.052995
# MANHEIM    0.042273
# OTHER      0.010722
# Name: Auction, dtype: float64
#
# --- Make ---
# 33
# CHEVROLET    0.055931
# DODGE        0.032395
# FORD         0.044668
# Name: Make, dtype: float64
#
# --- Model ---
# 1063
# IMPALA                  0.010892
# IMPALA V6               0.011257
# PT CRUISER              0.018999
# STRATUS V6 2.7L V6 M    0.010401
# Name: Model, dtype: float64
#
# --- Trim ---
# 134
# NaN    0.010639
# LS     0.045385
# LT     0.021643
# SXT    0.011741
# XLT    0.012081
# Name: Trim, dtype: float64
#
# --- SubModel ---
# 863
# 4D SEDAN LS         0.027344
# 4D SEDAN SXT FFV    0.013154
# Name: SubModel, dtype: float64
#
# --- Color ---
# 16
# BLACK    0.010166
# BLUE     0.010614
# GOLD     0.011897
# Name: Color, dtype: float64
#
# --- Transmission ---
# 3
# Series([], Name: Transmission, dtype: float64)
#
# --- WheelTypeID ---
# 5
# 1.0    0.056999
# 2.0    0.178362
# nan    0.234532
# Name: WheelTypeID, dtype: float64
#
# --- WheelType ---
# 3
# Alloy     0.056999
# Covers    0.178362
# NaN       0.234581
# Name: WheelType, dtype: float64
#
# --- Nationality ---
# 4
# AMERICAN    0.015077
# Name: Nationality, dtype: float64
#
# --- Size ---
# 12
# COMPACT       0.032885
# LARGE         0.034354
# MEDIUM        0.031145
# MEDIUM SUV    0.025156
# Name: Size, dtype: float64
#
# --- TopThreeAmericanName ---
# 4
# CHRYSLER    0.019409
# FORD        0.052262
# GM          0.047930
# OTHER       0.015155
# Name: TopThreeAmericanName, dtype: float64
#
# --- PRIMEUNIT ---
# 2
# NaN    0.036521
# NO     0.036314
# Name: PRIMEUNIT, dtype: float64
#
# --- AUCGUART ---
# 2
# NaN      0.036521
# GREEN    0.036303
# Name: AUCGUART, dtype: float64
#
# --- BYRNO ---
# 74
# 18880    0.012668
# 20740    0.010430
# 20833    0.014897
# 23359    0.012027
# 99750    0.031413
# 99761    0.033529
# Name: BYRNO, dtype: float64
#
# --- VNZIP1 ---
# 153
# 27542    0.011230
# 32824    0.013711
# 74135    0.018604
# Name: VNZIP1, dtype: float64
#
# --- VNST ---
# 37
# FL    0.018147
# OK    0.014103
# TX    0.026024
# Name: VNST, dtype: float64
#
# --- IsOnlineSale ---
# 2
# Series([], Name: IsOnlineSale, dtype: float64)

# %% [markdown]
# ##### Looking for highly correlated continuous features. VehAge is highly correlated with VehYear. MMRAcquisitonRetailCleanPrice is highly correlated with MMRQcquisitionRetailAverageprice. MMRAcquisitionAuctionCleanPrice is highly correlated with MMRAcquisitionAuctionAveragePrice, MMRCurrentRetailCleanPrice is highly correlated with MMRCurrentRetailAveragePrice, MMRCurrentAuctionCleanPrice is highly correlated with MMRCurrentAuctionAveragePrice

# %%
df_training[fact_cols].corr()
# Out:
#                                     VehYear  VehicleAge    VehOdo  \
# VehYear                            1.000000   -0.957957 -0.283719
# VehicleAge                        -0.957957    1.000000  0.319794
# VehOdo                            -0.283719    0.319794  1.000000
# MMRAcquisitionAuctionAveragePrice  0.581146   -0.565690 -0.017022
# MMRAcquisitionAuctionCleanPrice    0.532927   -0.518810  0.024617
# MMRAcquisitionRetailAveragePrice   0.581191   -0.460854  0.031306
# MMRAcquisitonRetailCleanPrice      0.539230   -0.426382  0.063165
# MMRCurrentAuctionAveragePrice      0.590820   -0.575607 -0.028568
# MMRCurrentAuctionCleanPrice        0.548426   -0.532505  0.012107
# MMRCurrentRetailAveragePrice       0.598490   -0.504062  0.015811
# MMRCurrentRetailCleanPrice         0.558669   -0.469359  0.048005
# VehBCost                           0.349965   -0.312329 -0.062008
# WarrantyCost                      -0.268696    0.259310  0.411718
#
#                                    MMRAcquisitionAuctionAveragePrice  \
# VehYear                                                     0.581146
# VehicleAge                                                 -0.565690
# VehOdo                                                     -0.017022
# MMRAcquisitionAuctionAveragePrice                           1.000000
# MMRAcquisitionAuctionCleanPrice                             0.990347
# MMRAcquisitionRetailAveragePrice                            0.910391
# MMRAcquisitonRetailCleanPrice                               0.910187
# MMRCurrentAuctionAveragePrice                               0.937817
# MMRCurrentAuctionCleanPrice                                 0.932492
# MMRCurrentRetailAveragePrice                                0.871755
# MMRCurrentRetailCleanPrice                                  0.871042
# VehBCost                                                    0.789840
# WarrantyCost                                               -0.050417
#
#                                    MMRAcquisitionAuctionCleanPrice  \
# VehYear                                                   0.532927
# VehicleAge                                               -0.518810
# VehOdo                                                    0.024617
# MMRAcquisitionAuctionAveragePrice                         0.990347
# MMRAcquisitionAuctionCleanPrice                           1.000000
# MMRAcquisitionRetailAveragePrice                          0.902718
# MMRAcquisitonRetailCleanPrice                             0.918242
# MMRCurrentAuctionAveragePrice                             0.923610
# MMRCurrentAuctionCleanPrice                               0.932114
# MMRCurrentRetailAveragePrice                              0.860716
# MMRCurrentRetailCleanPrice                                0.871203
# VehBCost                                                  0.781516
# WarrantyCost                                             -0.020644
#
#                                    MMRAcquisitionRetailAveragePrice  \
# VehYear                                                    0.581191
# VehicleAge                                                -0.460854
# VehOdo                                                     0.031306
# MMRAcquisitionAuctionAveragePrice                          0.910391
# MMRAcquisitionAuctionCleanPrice                            0.902718
# MMRAcquisitionRetailAveragePrice                           1.000000
# MMRAcquisitonRetailCleanPrice                              0.990201
# MMRCurrentAuctionAveragePrice                              0.851647
# MMRCurrentAuctionCleanPrice                                0.849407
# MMRCurrentRetailAveragePrice                               0.913108
# MMRCurrentRetailCleanPrice                                 0.906054
# VehBCost                                                   0.746126
# WarrantyCost                                              -0.053444
#
#                                    MMRAcquisitonRetailCleanPrice  \
# VehYear                                                 0.539230
# VehicleAge                                             -0.426382
# VehOdo                                                  0.063165
# MMRAcquisitionAuctionAveragePrice                       0.910187
# MMRAcquisitionAuctionCleanPrice                         0.918242
# MMRAcquisitionRetailAveragePrice                        0.990201
# MMRAcquisitonRetailCleanPrice                           1.000000
# MMRCurrentAuctionAveragePrice                           0.846914
# MMRCurrentAuctionCleanPrice                             0.855689
# MMRCurrentRetailAveragePrice                            0.903188
# MMRCurrentRetailCleanPrice                              0.906810
# VehBCost                                                0.744966
# WarrantyCost                                           -0.026933
#
#                                    MMRCurrentAuctionAveragePrice  \
# VehYear                                                 0.590820
# VehicleAge                                             -0.575607
# VehOdo                                                 -0.028568
# MMRAcquisitionAuctionAveragePrice                       0.937817
# MMRAcquisitionAuctionCleanPrice                         0.923610
# MMRAcquisitionRetailAveragePrice                        0.851647
# MMRAcquisitonRetailCleanPrice                           0.846914
# MMRCurrentAuctionAveragePrice                           1.000000
# MMRCurrentAuctionCleanPrice                             0.990329
# MMRCurrentRetailAveragePrice                            0.915073
# MMRCurrentRetailCleanPrice                              0.912231
# VehBCost                                                0.778738
# WarrantyCost                                           -0.056798
#
#                                    MMRCurrentAuctionCleanPrice  \
# VehYear                                               0.548426
# VehicleAge                                           -0.532505
# VehOdo                                                0.012107
# MMRAcquisitionAuctionAveragePrice                     0.932492
# MMRAcquisitionAuctionCleanPrice                       0.932114
# MMRAcquisitionRetailAveragePrice                      0.849407
# MMRAcquisitonRetailCleanPrice                         0.855689
# MMRCurrentAuctionAveragePrice                         0.990329
# MMRCurrentAuctionCleanPrice                           1.000000
# MMRCurrentRetailAveragePrice                          0.908669
# MMRCurrentRetailCleanPrice                            0.921536
# VehBCost                                              0.775100
# WarrantyCost                                         -0.028131
#
#                                    MMRCurrentRetailAveragePrice  \
# VehYear                                                0.598490
# VehicleAge                                            -0.504062
# VehOdo                                                 0.015811
# MMRAcquisitionAuctionAveragePrice                      0.871755
# MMRAcquisitionAuctionCleanPrice                        0.860716
# MMRAcquisitionRetailAveragePrice                       0.913108
# MMRAcquisitonRetailCleanPrice                          0.903188
# MMRCurrentAuctionAveragePrice                          0.915073
# MMRCurrentAuctionCleanPrice                            0.908669
# MMRCurrentRetailAveragePrice                           1.000000
# MMRCurrentRetailCleanPrice                             0.989760
# VehBCost                                               0.756816
# WarrantyCost                                          -0.058025
#
#                                    MMRCurrentRetailCleanPrice  VehBCost  \
# VehYear                                              0.558669  0.349965
# VehicleAge                                          -0.469359 -0.312329
# VehOdo                                               0.048005 -0.062008
# MMRAcquisitionAuctionAveragePrice                    0.871042  0.789840
# MMRAcquisitionAuctionCleanPrice                      0.871203  0.781516
# MMRAcquisitionRetailAveragePrice                     0.906054  0.746126
# MMRAcquisitonRetailCleanPrice                        0.906810  0.744966
# MMRCurrentAuctionAveragePrice                        0.912231  0.778738
# MMRCurrentAuctionCleanPrice                          0.921536  0.775100
# MMRCurrentRetailAveragePrice                         0.989760  0.756816
# MMRCurrentRetailCleanPrice                           1.000000  0.756662
# VehBCost                                             0.756662  1.000000
# WarrantyCost                                        -0.031683 -0.033210
#
#                                    WarrantyCost
# VehYear                               -0.268696
# VehicleAge                             0.259310
# VehOdo                                 0.411718
# MMRAcquisitionAuctionAveragePrice     -0.050417
# MMRAcquisitionAuctionCleanPrice       -0.020644
# MMRAcquisitionRetailAveragePrice      -0.053444
# MMRAcquisitonRetailCleanPrice         -0.026933
# MMRCurrentAuctionAveragePrice         -0.056798
# MMRCurrentAuctionCleanPrice           -0.028131
# MMRCurrentRetailAveragePrice          -0.058025
# MMRCurrentRetailCleanPrice            -0.031683
# VehBCost                              -0.033210
# WarrantyCost                           1.000000

# %%
df_training.shape
# Out:
# (72983, 34)

# %%
df_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72983 entries, 0 to 72982
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   RefId                              72983 non-null  object
#  1   IsBadBuy                           72983 non-null  object
#  2   PurchDate                          72983 non-null  object
#  3   Auction                            72983 non-null  object
#  4   VehYear                            72983 non-null  int64
#  5   VehicleAge                         72983 non-null  int64
#  6   Make                               72983 non-null  object
#  7   Model                              72983 non-null  object
#  8   Trim                               70623 non-null  object
#  9   SubModel                           72975 non-null  object
#  10  Color                              72975 non-null  object
#  11  Transmission                       72974 non-null  object
#  12  WheelTypeID                        72983 non-null  object
#  13  WheelType                          69809 non-null  object
#  14  VehOdo                             72983 non-null  int64
#  15  Nationality                        72978 non-null  object
#  16  Size                               72978 non-null  object
#  17  TopThreeAmericanName               72978 non-null  object
#  18  MMRAcquisitionAuctionAveragePrice  72965 non-null  float64
#  19  MMRAcquisitionAuctionCleanPrice    72965 non-null  float64
#  20  MMRAcquisitionRetailAveragePrice   72965 non-null  float64
#  21  MMRAcquisitonRetailCleanPrice      72965 non-null  float64
#  22  MMRCurrentAuctionAveragePrice      72668 non-null  float64
#  23  MMRCurrentAuctionCleanPrice        72668 non-null  float64
#  24  MMRCurrentRetailAveragePrice       72668 non-null  float64
#  25  MMRCurrentRetailCleanPrice         72668 non-null  float64
#  26  PRIMEUNIT                          3419 non-null   object
#  27  AUCGUART                           3419 non-null   object
#  28  BYRNO                              72983 non-null  object
#  29  VNZIP1                             72983 non-null  object
#  30  VNST                               72983 non-null  object
#  31  VehBCost                           72983 non-null  float64
#  32  IsOnlineSale                       72983 non-null  object
#  33  WarrantyCost                       72983 non-null  int64
# dtypes: float64(9), int64(4), object(21)
# memory usage: 18.9+ MB

# %%
sum(df_training['PRIMEUNIT'].isna() == True)
# Out:
# 69564

# %%
# Add Unknown type for missing category values
for col in dim_cols:
    df_training[col].fillna('Unknown',inplace=True)

# %%
for col in dim_cols_2:
    df_test[col].fillna('Unknown',inplace=True)

# %%
# Data imputation for missing continuous features with the mean
# imputer = SimpleImputer(strategy='mean');
# imputer.fit(df_training[fact_cols]);
# df_training[fact_cols]=imputer.transform(df_training[fact_cols]);
# df_test[fact_cols]=imputer.transform(df_test[fact_cols]);

# %% [markdown]
# ## Modeling

# %%
df_training['RefId']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 72978    73010
# 72979    73011
# 72980    73012
# 72981    73013
# 72982    73014
# Name: RefId, Length: 72983, dtype: object

# %%
# correlated cols to drop
unique_id_cols = ['RefId','BYRNO']
redundant_cols = ['WheelTypeID']
highly_correlated_cols = ['MMRCurrentAuctionCleanPrice','MMRCurrentRetailCleanPrice','MMRAcquisitionAuctionCleanPrice','MMRAcquisitonRetailCleanPrice','VehYear']
# cols with too many levels without categorization
high_levels_col = ['Model','Trim','SubModel']

drop_cols = unique_id_cols + redundant_cols + high_levels_col

# features and target cols
features = df_training.columns.copy().drop('IsBadBuy')
features = features.drop(drop_cols)
target = 'IsBadBuy'

dim_cols = dim_cols.drop(drop_cols)
dim_cols_2 = dim_cols_2.drop(drop_cols)

# %%
df_training.drop(drop_cols,axis=1,inplace=True)
# df_test.drop(drop_cols,axis=1,inplace=True)

# %%
# label-encode categorical columns
labelencoder = {}
for col in dim_cols:
    labelencoder[col] = preprocessing.LabelEncoder()
    df_training[col] = labelencoder[col].fit_transform(df_training[col])
labelencoder_test = {}
for col in dim_cols_2:
    labelencoder_test[col] = preprocessing.LabelEncoder()
    df_test[col] = labelencoder_test[col].fit_transform(df_test[col])

# %%
# df_training[target].unique()

# %%
# encoder = preprocessing.OneHotEncoder(sparse=False,handle_unknown='ignore')
# encoder.fit(df_training[dim_cols_2])
# encoded_cols = list(encoder.get_feature_names(dim_cols_2))

# df_training[encoded_cols]=encoder.transform(df_training[dim_cols_2]);
# df_test[encoded_cols]=encoder.transform(df_test[dim_cols_2]);

# %%
# Scale continuous columns with MinMaxScaler
scaler = preprocessing.MinMaxScaler()
scaler.fit(df_training[fact_cols]);
df_training[fact_cols]=scaler.transform(df_training[fact_cols])
df_test[fact_cols]=scaler.transform(df_test[fact_cols])

# %%
df_training['IsBadBuy'].unique()
# Out:
# array([0, 1])

# %%
# df_training.loc[df_training.loc[:,'IsBadBuy'] == 'nan','IsBadBuy'] = None

# %%
df_training.loc[df_training['IsBadBuy'].isna(),'IsBadBuy']
# Out:
# Series([], Name: IsBadBuy, dtype: int32)

# %%
X = df_training.loc[:,features]
y = df_training.loc[:,target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=25)

# %%
# Use Hyperparameter Optimization with Optuna

def objective(trail):

    alpha = trail.suggest_float("alpha", .0001, 1, step=.01, log=False)
    max_depth = trail.suggest_int("max_depth", 1, 10, log=False)
    reg_lambda = trail.suggest_float("reg_lambda", 0.01, 4, log=False)
    
    colsample_bytree = trail.suggest_float("colsample_bytree", 0.5, 1.0,step=.1, log=False)
    subsample = trail.suggest_float("subsample", 0.5, 1.0, step=.1, log=False)

    model  = xgb.XGBClassifier(max_depth=max_depth,learning_rate=alpha,n_estimators=200,grow_policy='depthwise',colsample_bytree=colsample_bytree,subsample=subsample,n_jobs=-1,eval_metric='error',reg_lambda=reg_lambda)
    # model  = xgb.XGBClassifier(booster='gbtree',max_depth=linear_max_depth,learning_rate=linear_alpha,n_estimators=500,grow_policy='depthwise',colsample_bytree=1,subsample=1,n_jobs=-1,eval_metric='rmse',reg_lambda=linear_reg_lambda)
    model.fit(X_train,y_train)

    # Predict on x_test
    preds = model.predict(X_test)

    error = accuracy_score(y_test, preds)
    
    return error

study = optuna.create_study(direction="maximize")  # Create a new study.
study.optimize(objective, n_trials=20)  # Invoke optimization of the objective function.
# Out:
# [I 2022-12-08 08:59:11,916] A new study created in memory with name: no-name-9bdbcdf2-150a-499f-9b9a-cfc57a85e4f2
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 08:59:18,961] Trial 0 finished with value: 0.9037049216266579 and parameters: {'alpha': 0.1701, 'max_depth': 7, 'reg_lambda': 1.902887230368362, 'colsample_bytree': 1.0, 'subsample': 1.0}. Best is trial 0 with value: 0.9037049216266579.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 08:59:28,987] Trial 1 finished with value: 0.9040337608242902 and parameters: {'alpha': 0.0201, 'max_depth': 9, 'reg_lambda': 0.5996056928234897, 'colsample_bytree': 1.0, 'subsample': 0.6}. Best is trial 1 with value: 0.9040337608242902.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 08:59:39,096] Trial 2 finished with value: 0.8815082757864737 and parameters: {'alpha': 0.5201, 'max_depth': 10, 'reg_lambda': 1.0525490801028068, 'colsample_bytree': 0.8, 'subsample': 0.5}. Best is trial 1 with value: 0.9040337608242902.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 08:59:50,062] Trial 3 finished with value: 0.9046366326866162 and parameters: {'alpha': 0.0301, 'max_depth': 10, 'reg_lambda': 0.49653796579627074, 'colsample_bytree': 0.5, 'subsample': 1.0}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 08:59:52,639] Trial 4 finished with value: 0.9008001753809054 and parameters: {'alpha': 0.050100000000000006, 'max_depth': 2, 'reg_lambda': 1.288492434859994, 'colsample_bytree': 0.8, 'subsample': 0.6}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 08:59:57,941] Trial 5 finished with value: 0.9033760824290256 and parameters: {'alpha': 0.21009999999999998, 'max_depth': 5, 'reg_lambda': 3.4366664002974945, 'colsample_bytree': 0.7, 'subsample': 0.9}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:00:05,428] Trial 6 finished with value: 0.9041433738901677 and parameters: {'alpha': 0.0801, 'max_depth': 7, 'reg_lambda': 1.7474014213255946, 'colsample_bytree': 0.5, 'subsample': 0.9}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:00:09,600] Trial 7 finished with value: 0.901293434177354 and parameters: {'alpha': 0.3401, 'max_depth': 4, 'reg_lambda': 3.808873793646025, 'colsample_bytree': 0.8, 'subsample': 0.7}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:00:11,300] Trial 8 finished with value: 0.8975117834045818 and parameters: {'alpha': 0.6601, 'max_depth': 1, 'reg_lambda': 1.4987266424904642, 'colsample_bytree': 0.5, 'subsample': 0.6}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:00:17,447] Trial 9 finished with value: 0.8935109065000548 and parameters: {'alpha': 0.4401, 'max_depth': 6, 'reg_lambda': 3.496108973860074, 'colsample_bytree': 0.7, 'subsample': 0.6}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:00:25,480] Trial 10 finished with value: 0.8836457305710841 and parameters: {'alpha': 0.8301000000000001, 'max_depth': 9, 'reg_lambda': 0.04184110829484561, 'colsample_bytree': 0.6, 'subsample': 1.0}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:00:32,934] Trial 11 finished with value: 0.9032664693631481 and parameters: {'alpha': 0.2201, 'max_depth': 8, 'reg_lambda': 2.6022300470812336, 'colsample_bytree': 0.5, 'subsample': 0.9}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:00:40,207] Trial 12 finished with value: 0.901074208045599 and parameters: {'alpha': 0.0001, 'max_depth': 7, 'reg_lambda': 2.5604275969319765, 'colsample_bytree': 0.6, 'subsample': 0.9}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:00:49,535] Trial 13 finished with value: 0.871643099857503 and parameters: {'alpha': 0.9801, 'max_depth': 10, 'reg_lambda': 0.09300888876115088, 'colsample_bytree': 0.5, 'subsample': 0.8}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:00:53,327] Trial 14 finished with value: 0.9018414995067412 and parameters: {'alpha': 0.3301, 'max_depth': 4, 'reg_lambda': 0.8047407775895397, 'colsample_bytree': 0.6, 'subsample': 1.0}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:01:01,367] Trial 15 finished with value: 0.903869341225474 and parameters: {'alpha': 0.1201, 'max_depth': 8, 'reg_lambda': 2.4691569030349716, 'colsample_bytree': 0.5, 'subsample': 0.8}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:01:07,531] Trial 16 finished with value: 0.9009645949797216 and parameters: {'alpha': 0.3001, 'max_depth': 6, 'reg_lambda': 1.7423468402189544, 'colsample_bytree': 0.6, 'subsample': 0.9}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:01:16,297] Trial 17 finished with value: 0.8868245094815302 and parameters: {'alpha': 0.5701, 'max_depth': 8, 'reg_lambda': 0.6120467428927412, 'colsample_bytree': 0.9, 'subsample': 0.8}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:01:26,729] Trial 18 finished with value: 0.9045818261536775 and parameters: {'alpha': 0.1301, 'max_depth': 10, 'reg_lambda': 2.1575669579409613, 'colsample_bytree': 0.7, 'subsample': 1.0}. Best is trial 3 with value: 0.9046366326866162.
# C:\Users\Edward.Moradian\anaconda3\envs\DataScience\lib\site-packages\optuna\distributions.py:668: UserWarning: The distribution is specified by [0.0001, 1] and step=0.01, but the range is not divisible by `step`. It will be replaced by [0.0001, 0.9901].
#   warnings.warn(
# [I 2022-12-08 09:01:37,065] Trial 19 finished with value: 0.9008001753809054 and parameters: {'alpha': 0.3801, 'max_depth': 10, 'reg_lambda': 2.2631167537856243, 'colsample_bytree': 0.7, 'subsample': 1.0}. Best is trial 3 with value: 0.9046366326866162.

# %%
# model = xgb.XGBClassifier(use_label_encoder=False,enable_categorical=False)
model = xgb.XGBClassifier(max_depth=10,learning_rate=0.0301,n_estimators=500,grow_policy='depthwise',colsample_bytree=0.5,subsample=1.0,n_jobs=-1,eval_metric='error',reg_lambda=0.49653796,use_label_encoder=False,enable_categorical=False)
# 'alpha': 0.15009999999999998, 'max_depth': 5, 'reg_lambda': 3.1625543630608752, 'colsample_bytree': 0.5, 'subsample': 0.7}
# 'alpha': 0.0301, 'max_depth': 10, 'reg_lambda': 0.49653796579627074, 'colsample_bytree': 0.5, 'subsample': 1.0

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='error', gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.0301, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=10, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=500,
#               n_jobs=-1, num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=0.49653796, ...)

# %%
# Make predictions using the model
preds = model.predict(X_test)

# %%
preds
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model.classes_
# Out:
# array([0, 1])

# %%
# Check for accuracy
scores = model.score(X_train,y_train)
scores
# Out:
# 0.9383963315490436

# %%
# model.score(X_test,y_test)

# %%
X_test['preds'] = preds

# %%
X_test.loc[X_test['preds']==1,:]
# Out:
#        PurchDate  Auction   VehYear  VehicleAge  Make  Color  Transmission  \
# 34036         67        1  0.555556    0.333333    13      1             0
# 66715        317        0  0.666667    0.333333    29     13             0
# 57350        221        2  0.444444    0.555556     4     13             0
# 24126        336        2  0.666667    0.222222    24     15             0
# 32958        127        2  0.666667    0.333333     6      6             0
# ...          ...      ...       ...         ...   ...    ...           ...
# 59022        289        1  0.222222    0.666667    22     10             0
# 54686        483        2  0.444444    0.444444     3     15             0
# 18065        445        2  0.444444    0.555556     6     12             0
# 17789        440        2  0.555556    0.333333     6      0             0
# 45555         49        2  0.000000    1.000000     6      8             0
#
#        WheelType    VehOdo  Nationality  Size  TopThreeAmericanName  \
# 34036          0  0.456543            0     3                     0
# 66715          3  0.604787            3     5                     3
# 57350          3  0.556325            0     1                     0
# 24126          3  0.537631            0     2                     2
# 32958          3  0.000000            0     5                     1
# ...          ...       ...          ...   ...                   ...
# 59022          3  0.638288            0     5                     2
# 54686          3  0.716896            0     0                     2
# 18065          3  0.604453            0    10                     1
# 17789          3  0.511831            0     0                     1
# 45555          3  0.797731            0    10                     1
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionAuctionCleanPrice  \
# 34036                           0.482308                         0.535690
# 66715                           0.284671                         0.301934
# 57350                           0.203768                         0.230364
# 24126                           0.218017                         0.251336
# 32958                           0.153911                         0.185708
# ...                                  ...                              ...
# 59022                           0.071665                         0.102146
# 54686                           0.138990                         0.169104
# 18065                           0.226247                         0.257522
# 17789                           0.122166                         0.147427
# 45555                           0.079139                         0.101359
#
#        MMRAcquisitionRetailAveragePrice  MMRAcquisitonRetailCleanPrice  \
# 34036                          0.488920                       0.526132
# 66715                          0.359135                       0.366472
# 57350                          0.260952                       0.280531
# 24126                          0.228019                       0.253242
# 32958                          0.256858                       0.301263
# ...                                 ...                            ...
# 59022                          0.083547                       0.110072
# 54686                          0.150000                       0.174341
# 18065                          0.285440                       0.305024
# 17789                          0.133393                       0.153536
# 45555                          0.150230                       0.164240
#
#        MMRCurrentAuctionAveragePrice  MMRCurrentAuctionCleanPrice  \
# 34036                       0.482616                     0.536341
# 66715                       0.284671                     0.301934
# 57350                       0.200605                     0.226078
# 24126                       0.218017                     0.251336
# 32958                       0.153603                     0.185545
# ...                              ...                          ...
# 59022                       0.071665                     0.102146
# 54686                       0.139606                     0.170867
# 18065                       0.223308                     0.255813
# 17789                       0.122166                     0.147427
# 45555                       0.079111                     0.098212
#
#        MMRCurrentRetailAveragePrice  MMRCurrentRetailCleanPrice  PRIMEUNIT  \
# 34036                      0.554964                    0.594126          1
# 66715                      0.359135                    0.370221          1
# 57350                      0.244703                    0.269641          1
# 24126                      0.228019                    0.255833          1
# 32958                      0.235926                    0.264868          1
# ...                             ...                         ...        ...
# 59022                      0.083547                    0.111198          1
# 54686                      0.150614                    0.177829          1
# 18065                      0.298849                    0.313672          1
# 17789                      0.133393                    0.155107          1
# 45555                      0.158495                    0.167089          1
#
#        AUCGUART  VNZIP1  VNST  VehBCost  IsOnlineSale  WarrantyCost  preds
# 34036         2     111     4  0.343093             0      0.159323      1
# 66715         2      20    19  0.223762             0      0.015208      1
# 57350         2      68    10  0.201218             0      0.107021      1
# 24126         2      26    30  0.147334             0      0.176379      1
# 32958         2      99    32  0.004927             0      0.025583      1
# ...         ...     ...   ...       ...           ...           ...    ...
# 59022         2     143     3  0.111925             0      0.191018      1
# 54686         2      87    27  0.107966             0      0.055571      1
# 18065         2     118    33  0.184943             1      0.048465      1
# 17789         2     118    33  0.136558             0      0.079306      1
# 45555         2     113     4  0.074976             0      0.106168      1
#
# [628 rows x 28 columns]

# %%
sorted_idx = model.feature_importances_.argsort()
plt.figure(figsize = (20,20))
plt.barh([X.columns[x] for x in sorted_idx], model.feature_importances_[sorted_idx])
plt.xlabel("Xgboost Feature Importance")
# Out:
# Text(0.5, 0, 'Xgboost Feature Importance')

# %% [markdown]
# #### predict for submission

# %%
preds_test = model.predict(df_test[features])

# %%
preds_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
df_submission = pd.DataFrame()

# %%
df_test['RefId']
# Out:
# 0         73015
# 1         73016
# 2         73017
# 3         73018
# 4         73019
#           ...
# 48702    121742
# 48703    121743
# 48704    121744
# 48705    121745
# 48706    121746
# Name: RefId, Length: 48707, dtype: int64

# %%
df_test[dim_cols_2]
# Out:
#        PurchDate  Auction  Make  Color  Transmission  WheelType  Nationality  \
# 0            138        0    22     14             0          0            0
# 1            138        0     3     14             0          0            0
# 2            138        0     5     14             0          0            0
# 3            138        0    23      4             0          0            0
# 4            138        0     9      2             0          3            2
# ...          ...      ...   ...    ...           ...        ...          ...
# 48702         94        1     6      1             0          0            0
# 48703         94        1    27      5             0          1            3
# 48704         94        1    13      1             0          1            2
# 48705         94        1    16     14             0          0            2
# 48706         94        1     1      4             0          1            0
#
#        Size  TopThreeAmericanName  PRIMEUNIT  AUCGUART  VNZIP1  VNST  \
# 0         2                     2          1         2      19     6
# 1         5                     2          1         2      19     6
# 2         6                     0          1         2      19     6
# 3         5                     2          1         2      19     6
# 4         0                     3          1         2      19     6
# ...     ...                   ...        ...       ...     ...   ...
# 48702     2                     1          1         2      32     5
# 48703     0                     3          1         2      32     5
# 48704     5                     3          0         0      32     5
# 48705     5                     3          0         0      32     5
# 48706     6                     2          0         0      32     5
#
#        IsOnlineSale
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 48702             0
# 48703             0
# 48704             0
# 48705             0
# 48706             0
#
# [48707 rows x 14 columns]

# %%
dim_cols_2
# Out:
# Index(['PurchDate', 'Auction', 'Make', 'Color', 'Transmission', 'WheelType',
#        'Nationality', 'Size', 'TopThreeAmericanName', 'PRIMEUNIT', 'AUCGUART',
#        'VNZIP1', 'VNST', 'IsOnlineSale'],
#       dtype='object')

# %%
for col in dim_cols_2:
    df_test[col] = labelencoder_test[col].inverse_transform(df_test[col])

# %%
df_submission['RefId'] = df_test['RefId']

# %%
df_submission['IsBadBuy'] = preds_test

# %%
df_submission
# Out:
#         RefId  IsBadBuy
# 0       73015         0
# 1       73016         0
# 2       73017         0
# 3       73018         0
# 4       73019         1
# ...       ...       ...
# 48702  121742         0
# 48703  121743         0
# 48704  121744         0
# 48705  121745         0
# 48706  121746         0
#
# [48707 rows x 2 columns]

# %%
df_submission.to_csv('C:/Users/Edward.Moradian/OneDrive - Microsoft/Desktop/Home/github/kaggle/dont get kicked/df_submission.csv',index=False)

# %% [markdown]
# #### Next Steps to take with more time: <br/>  1) Try different models like light gbm, logistic regression, random forests, and neural networks. With this type of tabular data, mutiple models can be candidates. <br/>  2) Try feature engineering with making interactions of variable - it might be that cars with wheel covers that are lowered priced with higher age are more likely to be bad buys. <br/> 3) Do a data imputation of continuous variables more complicated than the mean imputation that lead to a slightly decreased accuracy <br/> 4) Categorize categorical variables that have too many levels (if possible). Having too many levels makes it hard for the model to see patterns in the data
